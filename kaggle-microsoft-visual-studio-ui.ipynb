# %% [markdown]
# # **Microsoft Visual Studio (with UI)**
#
# Now you can code on Kaggle!
#
# **WARNING: COULD RISK YOUR KAGGLE FREE TIER ACC**
#
# Using colabcode to run this
#
# Credits: [Nick088](https://linktr.ee/Nick088)

# %%
# installation
from IPython.display import clear_output
import codecs
cc_rot13 = "pbynopbqr"
cc = codecs.decode(cc_rot13, 'rot 13')
# !pip install $cc
# !pip install pyngrok
from pyngrok import ngrok
clear_output()
print("Installed")

# %%
# run with ngrok ui

# Ngrok Tunnel
ngrok.set_auth_token("ngrok_tunnel_authtoken") # Replace 'ngrok_tunnel_authtoken' with your ngrok tunnel authtoken that you can get here: https://dashboard.ngrok.com/tunnels/authtokens/new

# !{cc} --port 8080
# you can change '8080' to any ports you want
# add --password above if you want to use a password, for example '--password nick088'
